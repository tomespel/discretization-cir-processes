# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize']=[20,10]

# %% [markdown]
# Paths given CIR second order scheme using normal and Y ditributions and exact scheme

# %%
x = []
for k in range(0,401):
    x.append(k/400)

# %%
mean_var = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/mean_var_cir2.csv', header=None)

# %%
mean = mean_var[1]; lower = mean_var[0]; upper = mean_var[2];

# %%
PathsCIR2 = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/paths_cir2.csv', header=None)

# %%
PathsEXACT = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/paths_exact.csv', header=None)

# %%
PathsCIR2_Y = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/paths_cir2_Y.csv', header=None)

# %%
plt.plot(x, PathsEXACT, label = 'CIR EXact');
plt.legend();
plt.plot(x, mean, "black", label = None); 
plt.plot(x, lower, linestyle = '--', color = "black", label = None); 
plt.plot(x, upper, linestyle = '--', color = "black", label = None);

# %%
plt.plot(x,PathsCIR2, label = "CIR2 N(0,1)"); 
plt.legend();
plt.plot(x, mean, "black", label = None); 
plt.plot(x, lower, linestyle = '--', color = "black", label = None); 
plt.plot(x, upper, linestyle = '--', color = "black", label = None);

# %%
plt.plot(x, PathsCIR2_Y, label = 'CIR2 Y');
plt.legend();
plt.plot(x, mean, "black", label = None); 
plt.plot(x, lower, linestyle = '--', color = "black", label = None); 
plt.plot(x, upper, linestyle = '--', color = "black", label = None);

# %% [markdown]
# Checking order of the scheme

# %%
order_1 = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/order_1.csv', header=None)

# %%
order_2 = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/order_2.csv', header=None)

# %%
order_1
# Out:
#           0         1
# 0  0.004350  0.001149
# 1  0.001551  0.000612
# 2  0.003950  0.000722
# 3  0.004601  0.000866
# 4  0.000709  0.000022
# 5  0.002054  0.000051
# 6  0.005319  0.001487
# 7  0.000839  0.000162
# 8  0.004456  0.001477

# %%
order_2
# Out:
#           0         1
# 0  0.005697  0.001240
# 1  0.011095  0.002547
# 2  0.004219  0.001411
# 3  0.001255  0.000069
# 4  0.000289  0.000028
# 5  0.006684  0.002012
# 6  0.001709  0.000183
# 7  0.002852  0.000488
# 8  0.002466  0.000733

# %%
x = []
y = []
for i in range(1, 10):
    x.append(np.log(i*100))
    #y.append()

# %%
plt.plot(x, -np.log(order_1[0]), 'o'); plt.plot(x, -np.log(order_1[0]), 'o');

# %% [markdown]
# CIR near 0 (Feller condition not satisfied)

# %%
x = []
for k in range(0,401):
    x.append(k/400)

# %%
PathsCIR2_B = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/paths_cir2_B.csv', header=None)

# %%
PathsCIR2_C = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/paths_cir2_C.csv', header=None)

# %%
plt.plot(x, PathsCIR2_B, label = 'CIR2 not Feller');
plt.legend();

# %%
plt.plot(x, PathsCIR2_C, label = 'CIR2 not Feller (large a)');
plt.legend();

# %% [markdown]
# Paper Plots A

# %%
fig_exp = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/plot_paper.csv', header=None)

# %%
cir2 = fig_exp[0]; exact = fig_exp[1]; b1 = fig_exp[4]; b3 = fig_exp[5];

# %%
fig_exp;
x = []
for i in range(1, 101):
    x.append(np.log(i))

# %%
plt.plot(x, cir2, "blue", label = 'CIR2');plt.plot(x, exact, "green", label = 'Exact Scheme'); plt.plot(x, np.full(100, 0.34037), "black", label = 'Exact value');
plt.legend();
#plt.plot(b1, "orange");#plt.plot(b3, "red");

# %%
plt.plot(x,cir2, "blue", label = 'CIR2');plt.plot(x,exact, "green", label = 'Exact Scheme'); plt.plot(x,np.full(100, 0.34037), "black", label = 'Exact value');
plt.plot(x,b1, "orange" , label = 'sqrt(+)');plt.plot(x,b3, "red", label = 'abs');
plt.legend();

# %%
plt.plot(x[30:],cir2[30:], "blue", label = 'CIR2');
plt.plot(x[30:],exact[30:], "green", label = 'Exact Scheme'); plt.plot(x[30:],np.full(70, 0.34037), "black", label = 'Exact value');
plt.plot(x[30:],b1[30:], "orange" , label = 'sqrt(+)');plt.plot(x[30:],b3[30:], "red", label = 'abs');
plt.legend();

# %% [markdown]
# Paper Plots B (Feller condition not satisfied)

# %%
fig_exp_B_1 = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/output/plot_paper_B_1.csv', header=None)

# %%
cir2 = fig_exp_B_1[0]; exact = fig_exp_B_1[1]; cir2_32=fig_exp_B_1[2]; cir2_12=fig_exp_B_1[3]; b1 = fig_exp_B_1[4]; b3 = fig_exp_B_1[5];

# %%
plt.plot(cir2, "blue", label = 'CIR2');
plt.plot(cir2_32, "purple", label = 'CIR2 3K/2');
plt.plot(cir2_12, label = 'CIR2 K/2'); #Need to rerun, should be erratic anyway
#plt.plot(exact, "green", label = 'Exact Scheme'); 
plt.plot(np.full(50, 0.89153), "black", label = 'Exact value');
#plt.plot(b1, "orange" , label = 'sqrt(+)');
#plt.plot(b3, "red", label = 'abs');
plt.legend();

# %%
plt.plot(cir2, "blue", label = 'CIR2');
plt.plot(cir2_32, "purple", label = 'CIR2 3K/2');
plt.plot(cir2_12, label = 'CIR2 K/2');
plt.plot(exact, "green", label = 'Exact Scheme'); 
plt.plot(np.full(50, 0.89153), "black", label = 'Exact value');
plt.plot(b1, "orange" , label = 'sqrt(+)');
plt.plot(b3, "red", label = 'abs');
plt.legend();
