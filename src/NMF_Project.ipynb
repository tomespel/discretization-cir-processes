# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize']=[7,4]

# %%
PathsCIR2 = pd.read_csv('C:/Users/Kees/Desktop/MSc/VS2017/Projects/NMF_Project/NMF_Project/NMF_Project/PathsCIR2.csv')

# %%
plt.plot(PathsCIR2);
